# %% [markdown]
# ## Variables :
# - Introduction to Variables
# - Declaring and Assigning Variables
# - Naming Conventions
# - Understanding Variables Types
# - Type Checking and Conversion
# - Dynamic Typing
# - Practical Examples and Common Errors

# %%
# Declating and Assgning Variables 
age = 24 
height = 5.8
name = "Rahul Verma"
is_student  = True
print("age : ", age)
print("Height : ", height)
print("Name : ",name)
# Out:
# age :  24
# Height :  5.8
# Name :  Rahul Verma

# %%
# Naming Convention 
# Variable Names should be descriptive 
## They must always start with a letter or an '_' and contains letter , number and underscores 
# Variables names are case Sensitive 

# Valid Variable Names 
first_name = "Rahul" 
last_name = "Verma"

# %%
# Invalid Variable Names 

2age = 32
first-name = "Rahul"
# Out:
#   Cell In[9], line 3
#     2age = 32
#     ^
# SyntaxError: invalid decimal literal

# %%
# Understanding Variable Types 
## Python is dynamically typed , type of a variable is determined at RunTime 
age = 25 #int 
height = 6.1  #float 
name = "Rahul" #string 
is_student = False #bool
print(type(name))
# Out:
# <class 'str'>

# %%
# Type Checking and Conversion 
type(height)
# Out:
# float

# %%
age = 25
print(type(age))

# Type Conversion 
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age = '25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name = "Rahul" 
print(int(name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 name = "Rahul"
# ----> 2 print(int(name))
#
# ValueError: invalid literal for int() with base 10: 'Rahul'

# %%
height = 5.8 
print(type(height))
height =(int(height))
print(float(height))
# Out:
# <class 'float'>
# 5.0

# %%
# Dynamic Typing 
#Python allows the type of a variable to change as the program executes
var = 10
print(var,type(var))

var = "Hello"
print(var , type(var))

var = 3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input 
age = int(input("What is the age ?"))
print(age, type(age))
# Out:
# 24 <class 'int'>
